# %% [markdown]
# #Aswin Chander N
# #19BCE1034
# #Assignment 3 Data Visualization

# %%
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
Goals = [50,100,200,300,400,500,600,700]
Age = [22,23,26,28,30,32,35,36]
plt.plot(Goals, Age)
plt.title('Ronaldo goal distribution')
plt.xlabel('Goals')
plt.ylabel('Age')
plt.show()

# %%
plt.scatter(Goals, Age)
plt.title('Ronaldo goal distribution')
plt.xlabel('Goals')
plt.ylabel('Age')
plt.show()

# %%
plt.bar(Goals,Age,color="Blue",width=20)
plt.title('Ronaldo goal distribution')
plt.xlabel('Goals')
plt.ylabel('Age')
plt.show()

# %%
sns.set(style="darkgrid")
df = sns.load_dataset("iris")
sns.histplot(data=df, x="sepal_length", color="red", label="Sepal Length", kde=True)
plt.legend() 
plt.show()

# %%
Weight=[50,55,60,65,70,75,80,85,90]
age=[20,25,30,35,40,45,50,55,60]
plt.hist(Weight,age,histtype='bar',rwidth=0.9)
# Out:
# (array([0., 0., 0., 0., 0., 0., 1., 2.]),
#  array([20, 25, 30, 35, 40, 45, 50, 55, 60]),
#  <a list of 8 Patch objects>)

# %%
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(x='class',data=titanic)

# %%
sns.heatmap(titanic.corr(),annot=True)

# %%
tips=sns.load_dataset("tips")
sns.pairplot(tips,hue='time')

# %%
sns.jointplot(x='tip',y='total_bill',data=tips)

# %%
sns.kdeplot(data=tips)
